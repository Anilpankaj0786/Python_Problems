# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
a={"stu_id":[1,2,3],
   "name":["anil","pankaj","Rohit"],
   "course":["cs","it","electrical"],
   "roll_no":[678,745,543],
  }
df=pd.DataFrame(a)
df
# Out:
#    stu_id    name      course  roll_no
# 0       1    anil          cs      678
# 1       2  pankaj          it      745
# 2       3   Rohit  electrical      543

# %%
df.to_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\stu_data.csv")

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\stu_data.csv")

# %%
df
# Out:
#    Unnamed: 0  stu_id    name      course  roll_no
# 0           0       1    anil          cs      678
# 1           1       2  pankaj          it      745
# 2           2       3   Rohit  electrical      543

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\flipkart.csv")

# %%
df
# Out:
#                                           CGtC98 href  \
# 0   https://www.flipkart.com/samsung-galaxy-s25-ul...
# 1   https://www.flipkart.com/nothing-phone-3a-pro-...
# 2   https://www.flipkart.com/vivo-v40-pro-5g-gange...
# 3   https://www.flipkart.com/samsung-galaxy-s24-5g...
# 4   https://www.flipkart.com/samsung-galaxy-s25-ul...
# 5   https://www.flipkart.com/samsung-galaxy-s25-ul...
# 6   https://www.flipkart.com/apple-iphone-16-plus-...
# 7   https://www.flipkart.com/samsung-galaxy-s25-5g...
# 8   https://www.flipkart.com/samsung-galaxy-s24-ul...
# 9   https://www.flipkart.com/apple-iphone-16-black...
# 10  https://www.flipkart.com/samsung-galaxy-s25-ul...
# 11  https://www.flipkart.com/samsung-galaxy-s25-ul...
# 12  https://www.flipkart.com/vivo-v50-5g-rose-red-...
# 13  https://www.flipkart.com/samsung-galaxy-s24-fe...
# 14  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 15  https://www.flipkart.com/samsung-galaxy-s24-fe...
# ...

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\flipkart.csv")
df
# Out:
#                                            visit_link         compare  \
# 0   https://www.flipkart.com/samsung-galaxy-s25-ul...  Add to Compare
# 1   https://www.flipkart.com/nothing-phone-3a-pro-...  Add to Compare
# 2   https://www.flipkart.com/vivo-v40-pro-5g-gange...  Add to Compare
# 3   https://www.flipkart.com/samsung-galaxy-s24-5g...  Add to Compare
# 4   https://www.flipkart.com/samsung-galaxy-s25-ul...  Add to Compare
# 5   https://www.flipkart.com/samsung-galaxy-s25-ul...  Add to Compare
# 6   https://www.flipkart.com/apple-iphone-16-plus-...  Add to Compare
# 7   https://www.flipkart.com/samsung-galaxy-s25-5g...  Add to Compare
# 8   https://www.flipkart.com/samsung-galaxy-s24-ul...  Add to Compare
# 9   https://www.flipkart.com/apple-iphone-16-black...  Add to Compare
# 10  https://www.flipkart.com/samsung-galaxy-s25-ul...  Add to Compare
# 11  https://www.flipkart.com/samsung-galaxy-s25-ul...  Add to Compare
# ...

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\google.csv")
df
# Out:
#                                           Best_places  \
# 0                                                 NaN
# 1   https://www.tourism.rajasthan.gov.in/jaipur.ht...
# 2   https://www.tripadvisor.in/Attractions-g304555...
# 3    https://www.tourism.rajasthan.gov.in/jaipur.html
# 4   https://chokhidhani.com/tourist-places-in-jaipur/
# 5   https://www.abhibus.com/blog/places-to-visit-i...
# 6   https://all.accor.com/a/en/limitless/thematics...
# 7   https://www.makemytrip.com/tripideas/places-to...
# 8   https://www.holidify.com/places/jaipur/sightse...
# 9   https://www.youtube.com/watch?v=Lv0PkSkKeSo&pp...
# 10  https://en.wikipedia.org/wiki/List_of_tourist_...
# 11  https://jaipurtourism.co.in/places-to-visit-in...
#
#                                          Guides_Place  \
# 0                                                 NaN
# 1   Places to Visit, Sightseeing, Trip to Jaipur -...
# 2        THE 30 BEST Places to Visit in Jaipur (2025)
# ...

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\food.csv")
df
# Out:
#                        Txngnb       pEWLJ  \
# 0                         NaN         NaN
# 1                         NaN         NaN
# 2                         NaN         NaN
# 3                         NaN         NaN
# 4  Can't update your location  Learn more
# 5                         NaN         NaN
# 6  Can't update your location  Learn more
#
#                                               VtPCGb            Txngnb 2
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4  .pEWLJ{white-space:normal}.UwURDc{padding:14px 0}  Updating location…
# 5                                                NaN                 NaN
# 6                                    Update location  Updating location…

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.tail(2)
# Out:
#     age  gender  fever   cough     city has_covid
# 98    5  Female   98.0  Strong   Mumbai        No
# 99   10  Female   98.0  Strong  Kolkata       Yes

# %%
df.shape
# Out:
# (100, 6)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender'][0]='Female'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ...

# %%
df.head(3)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60  Female  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No

# %%
df2=df.copy()

# %%
df2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60  Female  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2['gender']=df2['gender'].map({"Female":0,"Male":1})

# %%
df2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60       0  103.0    Mild    Kolkata        No
# 1    27       1  100.0    Mild      Delhi       Yes
# 2    42       1  101.0    Mild      Delhi        No
# 3    31       0   98.0    Mild    Kolkata        No
# 4    65       0  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12       0  104.0    Mild  Bangalore        No
# 96   51       0  101.0  Strong    Kolkata       Yes
# 97   20       0  101.0    Mild  Bangalore        No
# 98    5       0   98.0  Strong     Mumbai        No
# 99   10       0   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2['Gender']=df2['gender'].map({"Female":0,"Male":1})

# %%
df2
# Out:
#     age  gender  fever   cough       city has_covid  Gender
# 0    60       0  103.0    Mild    Kolkata        No     NaN
# 1    27       1  100.0    Mild      Delhi       Yes     NaN
# 2    42       1  101.0    Mild      Delhi        No     NaN
# 3    31       0   98.0    Mild    Kolkata        No     NaN
# 4    65       0  101.0    Mild     Mumbai        No     NaN
# ..  ...     ...    ...     ...        ...       ...     ...
# 95   12       0  104.0    Mild  Bangalore        No     NaN
# 96   51       0  101.0  Strong    Kolkata       Yes     NaN
# 97   20       0  101.0    Mild  Bangalore        No     NaN
# 98    5       0   98.0  Strong     Mumbai        No     NaN
# 99   10       0   98.0  Strong    Kolkata       Yes     NaN
#
# [100 rows x 7 columns]

# %%
df2=df2.drop(columns=['Gender'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df2=df2.drop(columns=['Gender'])
#
# NameError: name 'df2' is not defined

# %%
df2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60       0  103.0    Mild    Kolkata        No
# 1    27       1  100.0    Mild      Delhi       Yes
# 2    42       1  101.0    Mild      Delhi        No
# 3    31       0   98.0    Mild    Kolkata        No
# 4    65       0  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12       0  104.0    Mild  Bangalore        No
# 96   51       0  101.0  Strong    Kolkata       Yes
# 97   20       0  101.0    Mild  Bangalore        No
# 98    5       0   98.0  Strong     Mumbai        No
# 99   10       0   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2['cough']=df2['cough'].map({"Mild":0,"Strong":1})
df2
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       0  103.0      0    Kolkata        No
# 1    27       1  100.0      0      Delhi       Yes
# 2    42       1  101.0      0      Delhi        No
# 3    31       0   98.0      0    Kolkata        No
# 4    65       0  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      0  Bangalore        No
# 96   51       0  101.0      1    Kolkata       Yes
# 97   20       0  101.0      0  Bangalore        No
# 98    5       0   98.0      1     Mumbai        No
# 99   10       0   98.0      1    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2['city']=df2['city'].map({"Kolkata":0,"Delhi":1,"Mumbai":2,"Bangalore":3})
df2
# Out:
#     age  gender  fever  cough  city has_covid
# 0    60       0  103.0      0     0        No
# 1    27       1  100.0      0     1       Yes
# 2    42       1  101.0      0     1        No
# 3    31       0   98.0      0     0        No
# 4    65       0  101.0      0     2        No
# ..  ...     ...    ...    ...   ...       ...
# 95   12       0  104.0      0     3        No
# 96   51       0  101.0      1     0       Yes
# 97   20       0  101.0      0     3        No
# 98    5       0   98.0      1     2        No
# 99   10       0   98.0      1     0       Yes
#
# [100 rows x 6 columns]

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 21.01    2
# 20.69    2
# 10.33    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# tip
# 2.00    33
# 3.00    23
# 4.00    12
# 2.50    10
# 5.00    10
#         ..
# 1.47     1
# 1.17     1
# 4.67     1
# 5.92     1
# 1.75     1
# Name: count, Length: 123, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df2=df.copy()
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2['Add']=df2['sex'].map({"Female":1,"Male":0})
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  Add
# 0         16.99  1.01  Female     No   Sun  Dinner     2    1
# 1         10.34  1.66    Male     No   Sun  Dinner     3    0
# 2         21.01  3.50    Male     No   Sun  Dinner     3    0
# 3         23.68  3.31    Male     No   Sun  Dinner     2    0
# 4         24.59  3.61  Female     No   Sun  Dinner     4    1
# ..          ...   ...     ...    ...   ...     ...   ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    0
# 242       17.82  1.75    Male     No   Sat  Dinner     2    0
# 243       18.78  3.00  Female     No  Thur  Dinner     2    1
#
# [244 rows x 8 columns]

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  Add
# 0         16.99  1.01  Female     No   Sun  Dinner     2    1
# 1         10.34  1.66    Male     No   Sun  Dinner     3    0
# 2         21.01  3.50    Male     No   Sun  Dinner     3    0
# 3         23.68  3.31    Male     No   Sun  Dinner     2    0
# 4         24.59  3.61  Female     No   Sun  Dinner     4    1
# ..          ...   ...     ...    ...   ...     ...   ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    0
# 242       17.82  1.75    Male     No   Sat  Dinner     2    0
# 243       18.78  3.00  Female     No  Thur  Dinner     2    1
#
# [244 rows x 8 columns]

# %%
df2=df2.drop(columns=['Add'])
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2['sex']=df2['sex'].map({"Female":0,"Male":1})
df2
# Out:
#      total_bill   tip  sex smoker   day    time  size
# 0         16.99  1.01    0     No   Sun  Dinner     2
# 1         10.34  1.66    1     No   Sun  Dinner     3
# 2         21.01  3.50    1     No   Sun  Dinner     3
# 3         23.68  3.31    1     No   Sun  Dinner     2
# 4         24.59  3.61    0     No   Sun  Dinner     4
# ..          ...   ...  ...    ...   ...     ...   ...
# 239       29.03  5.92    1     No   Sat  Dinner     3
# 240       27.18  2.00    0    Yes   Sat  Dinner     2
# 241       22.67  2.00    1    Yes   Sat  Dinner     2
# 242       17.82  1.75    1     No   Sat  Dinner     2
# 243       18.78  3.00    0     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2['smoker']=df2['smoker'].map({"No":0,"Yes":1})
df2
# Out:
#      total_bill   tip  sex  smoker   day    time  size
# 0         16.99  1.01    0       0   Sun  Dinner     2
# 1         10.34  1.66    1       0   Sun  Dinner     3
# 2         21.01  3.50    1       0   Sun  Dinner     3
# 3         23.68  3.31    1       0   Sun  Dinner     2
# 4         24.59  3.61    0       0   Sun  Dinner     4
# ..          ...   ...  ...     ...   ...     ...   ...
# 239       29.03  5.92    1       0   Sat  Dinner     3
# 240       27.18  2.00    0       1   Sat  Dinner     2
# 241       22.67  2.00    1       1   Sat  Dinner     2
# 242       17.82  1.75    1       0   Sat  Dinner     2
# 243       18.78  3.00    0       0  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2['time']=df2['time'].map({"Dinner":0,"Lunch":1})
df2
# Out:
#      total_bill   tip  sex  smoker   day  time  size
# 0         16.99  1.01    0       0   Sun     0     2
# 1         10.34  1.66    1       0   Sun     0     3
# 2         21.01  3.50    1       0   Sun     0     3
# 3         23.68  3.31    1       0   Sun     0     2
# 4         24.59  3.61    0       0   Sun     0     4
# ..          ...   ...  ...     ...   ...   ...   ...
# 239       29.03  5.92    1       0   Sat     0     3
# 240       27.18  2.00    0       1   Sat     0     2
# 241       22.67  2.00    1       1   Sat     0     2
# 242       17.82  1.75    1       0   Sat     0     2
# 243       18.78  3.00    0       0  Thur     0     2
#
# [244 rows x 7 columns]

# %%
df2['s']=df2['smoker'].map({"No":0,"Yes":1})
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2['s']=df2['smoker'].map({"No":0,"Yes":1})
#       2 df2
#
# NameError: name 'df2' is not defined

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(100)

# %%
df['fever'].mean()
# Out:
# np.float64(100.76)

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
# Loc And Iloc 

# df.loc[row_range , column_name]  ---> Last index value will be include . 
# df.iloc[row_range , column_range] ---> Last index value will not be include .

# %%
df.loc[2:5 , ['age' , 'gender' , 'has_covid']]
# Out:
#    age  gender has_covid
# 2   42    Male        No
# 3   31  Female        No
# 4   65  Female        No
# 5   84  Female       Yes

# %%
df.iloc[2:5 , [0,1,2]]
# Out:
#    age  gender  fever
# 2   42    Male  101.0
# 3   31  Female   98.0
# 4   65  Female  101.0

# %%
df2 = df.copy()

# %%
df2.loc[2:5 , ['age' , 'fever']] = 900

# %%
df2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2   900    Male  900.0    Mild      Delhi        No
# 3   900  Female  900.0    Mild    Kolkata        No
# 4   900  Female  900.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2['Gender'] = df2['gender'].map({"Male":0 , "Female":1}) ## map() will apply on gender column and
# change male to 0 and female to 1 .

# %%
df2 = df2.drop(columns = ['Gender'])

# %%
# df = df.drop(columns = ['Gender'])  ### for delete a column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = df.drop(columns = ['Gender'])  ### for delete a column
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
df.sort_index()    ### for sequence wise sorting
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df = df.rename(columns = {
    "gender" : "Updated_gender" , 
    "fever" :  "Latest_updated_fever"
})

# %%
df.head(3)
# Out:
#    age Updated_gender  Latest_updated_fever cough     city has_covid
# 0   60           Male                 103.0  Mild  Kolkata        No
# 1   27           Male                 100.0  Mild    Delhi       Yes
# 2   42           Male                 101.0  Mild    Delhi        No

# %%
df = df[['age' , 'Latest_updated_fever' , 'has_covid']]

# %%
df
# Out:
#     age  Latest_updated_fever has_covid
# 0    60                 103.0        No
# 1    27                 100.0       Yes
# 2    42                 101.0        No
# 3    31                  98.0        No
# 4    65                 101.0        No
# ..  ...                   ...       ...
# 95   12                 104.0        No
# 96   51                 101.0       Yes
# 97   20                 101.0        No
# 98    5                  98.0        No
# 99   10                  98.0       Yes
#
# [100 rows x 3 columns]

# %%
df2.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2  900   Male  900.0  Mild    Delhi        No

# %%
df2.loc[2:5 , ['age' , 'gender' , 'has_covid']] = None

# %%
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Panda\\tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.sort_index()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
